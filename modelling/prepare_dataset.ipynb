# %%
import pandas as pd

# %%
# read reviews file
with open('test.ft.txt', 'r', encoding="utf8") as f:
    contents = f.readlines()

# %%
# create a blank reviews dictionary
reviews = {
    'review': [],
    'label': [],
}

# iterate over contents and push them in the reviews dictionary
for content in contents:
    label = reviews['label'].append(content[0:10])
    review = reviews['review'].append(content[11:-1])
    
# create dataframe from reviews dictionary 
dataframe = pd.DataFrame(reviews)

# convert labels from text to number
dataframe['label'] = dataframe['label'].apply(lambda label: 0 if label == '__label__1' else 1)

# %%
dataframe.to_csv('Amazon_Reviews_All.csv', index=False)

# %%
# count positive and negative labels
dataframe['label'].value_counts()
# Out:
# 1    200000
# 0    200000
# Name: label, dtype: int64

# %%
positive = dataframe[dataframe['label'] == 1].iloc[0:7500]

# %%
negative = dataframe[dataframe['label'] == 0].iloc[0:7500]

# %%
final = positive.append(negative)

# %%
# randomize the dataset
final = final.sample(frac=1)

# save to file
final.to_csv('Amazon_Reviews.csv', index=False)

# %%
positive
# Out:
#                                                   review  label
# 0      Great CD: My lovely Pat has one of the GREAT v...      1
# 1      One of the best game music soundtracks - for a...      1
# 3      works fine, but Maha Energy is better: Check o...      1
# 4      Great for the non-audiophile: Reviewed quite a...      1
# 8      Unique Weird Orientalia from the 1930's: Exoti...      1
# 10     Great book for travelling Europe: I currently ...      1
# 13     TRULY MADE A DIFFERENCE!: I have been using th...      1
# 16     Simple, Durable, Fun game for all ages: This i...      1
# 17     Review of Kelly Club for Toddlers: For the pri...      1
# 18     SOY UN APASIONADO DEL BOX: Y ESTE LIBRO ESTÁ E...      1
# 19     Some of the best fiddle playing I have heard i...      1
# 22     one of the last in the series to collect !: Th...      1
# 23     Sony Hi8 Camcorder with 2.5 LCD: I believe I w...      1
# 26     works great: i bought this item to connect to ...      1
# 28     wish i had gotten this sooner!: ive got a lamp...      1
# 30     This is the all time best book!: This is the a...      1
# 31     Mary Ash: Can't believe I have never reviewed ...      1
# 32     Tha BOMB of a book!!: L.J. Smith is the best a...      1
# 33     This book was a great book that i have read ma...      1
# 34     They'd watch it nonstop if I'd let them: apart...      1
# 36     Wonderful: I went online for information about...      1
# 38     Book of Chance: I had just finished reading 'T...      1
# 40     WeiB FOREVER!: This is a great CD!! I love Wei...      1
# 42     Real HTML for people who build sites for a liv...      1
# 43     Marriage has its good and bad moments: This is...      1
# 44     Amazing...: love it...very touch.it's to bad t...      1
# 45     Leslie in a nutshell: Danelectro DJ-20C Rocky ...      1
# 49     Patricia Cornwell has turned me into a reader:...      1
# 50     Best of the First Four in this series.: This i...      1
# 51     Great Beginning...poor ending: Parricia Corwel...      1
# ...                                                  ...    ...
# 14694  If I Could I Would Give It 10 Stars.: I love a...      1
# 14698  Babe, Pig in the City: It was fascinating how ...      1
# 14703  Nice happy Fluke stuff!: I actually have the v...      1
# 14709  what dreams my come: This is one of my most fa...      1
# 14710  Visual delight with ethical dilemmas: I enjoy ...      1
# 14715  Loved Even By A Truck Driver: My husband picke...      1
# 14716  This is by far the best movie I have ever seen...      1
# 14723  Best of the options...: Given that the best pe...      1
# 14726  Nice style, but did I miss something?: Okay, t...      1
# 14727  gritty realism...: Michael Connelly is an amaz...      1
# 14728  Good book...: Sorry for my english, i don't th...      1
# 14729  I remember Harry: I have to agree with other r...      1
# 14731  The First Lady of Country Music...: An AMAZING...      1
# 14732  Good starter set: This is an excellent basic s...      1
# 14734  Black Beauty: I love this book I would give it...      1
# 14743  funny as hell: this is bad, really bad but tha...      1
# 14745  Super Sticky Once or Twice: Super Sticky PostI...      1
# 14747  Great movie, keeps you guessing: We watched (m...      1
# 14748  Get it you won't regret it: I could rate this ...      1
# 14749  Fine Surreal Film: Terry Gilliam at his best. ...      1
# 14751  12 Monkeys Brad: This movie is really great, w...      1
# 14753  great deal: I could not locate any copies wher...      1
# 14756  Robert Jacks is the best Leatherface ever!: Fi...      1
# 14769  nice large face that is easy to read: Well mad...      1
# 14771  nice watch -- what I was looking for: nice wat...      1
# 14772  SOUTH OF THE BORDER SOUNDS: I AM BY NO MEANS A...      1
# 14773  Not the usually R. Kelly, but still pretty goo...      1
# 14777  first and best: One of the best Tom Berenger m...      1
# 14778  This was the GREATEST movie I have ever seen.:...      1
# 14779  Excellent shoes!: I've been searching everywhe...      1
#
# [7500 rows x 2 columns]

# %%
negative
# Out:
#                                                   review  label
# 2      Batteries died within a year ...: I bought thi...      0
# 5      DVD Player crapped out after one year: I also ...      0
# 6      Incorrect Disc: I love the style of this, but ...      0
# 7      DVD menu select problems: I cannot scroll thro...      0
# 9      Not an "ultimate guide": Firstly,I enjoyed the...      0
# 11     Not!: If you want to listen to El Duke , then ...      0
# 12     A complete Bust: This game requires quicktime ...      0
# 14     didn't run off of USB bus power: Was hoping th...      0
# 15     Don't buy!: First of all, the company took my ...      0
# 20     Long and boring: I've read this book with much...      0
# 21     Dont like it: This product smells when you ope...      0
# 24     Don't Take the Chance - Get the SE Branded Cab...      0
# 25     Waste of money!: Like many of the Barbie CD Ro...      0
# 27     Has No Range: I suppose if you were going to s...      0
# 29     Three Days of Use and It Broke: Very disappoin...      0
# 35     Not as expected...: My children get easily bor...      0
# 37     Doublecharged for shipping because merchant wa...      0
# 39     Light reading, light in substance: A clichéd s...      0
# 41     Great Book--unacceptable condition: I was look...      0
# 46     More Romance Please and Less Mystery!!: the re...      0
# 47     A Lost Author: I have read all of the Carpathi...      0
# 48     Okay but Messy....: We purchased this bag for ...      0
# 52     12 Y/O Potty Humor From 40 somethings does not...      0
# 53     I wish Adam Sandler wasn't in this.: I should ...      0
# 56     Disappointment at it's extreme: I had never re...      0
# 61     Predictable & has a lame ending: I have read a...      0
# 63     A historical gem whose title obscures its inte...      0
# 64     Vastly overrated work of fiction: I was sorely...      0
# 67     Had to return it: The sizing is perfect and a ...      0
# 68     Broke the 2nd time I wore it, great until then...      0
# ...                                                  ...    ...
# 15149  torture your ears: I have purchased 7 or 8 dif...      0
# 15150  twist to fit doesn't work: They work fine as r...      0
# 15151  Don't buy if your ears are on the small side: ...      0
# 15154  Addons are easily lost: After the first day ru...      0
# 15155  False advertising by Motorola--do not buy: 1) ...      0
# 15157  Doesn't last very long.: I suppose it's doing ...      0
# 15158  Smelly & Disgusting: Thinking I would save a f...      0
# 15160  singing dectitves: singing ectectves was an en...      0
# 15163  Sad: It is sad when a group of people lower th...      0
# 15164  Written in 1983, this book is due for a much n...      0
# 15165  NOT A Vpars Bible: Having already read much li...      0
# 15166  Take Heed!: As most of the other reviewers hea...      0
# 15167  Not So Much.: All I can say, I tossed not one ...      0
# 15168  Zero stars isn't an option, or I would!: I agr...      0
# 15170  Rehash minus one: As it was pointed out by ano...      0
# 15172  Rivets Bulge: The knife has good looks as far ...      0
# 15174  Too Big and Annoying: Bought these for sportin...      0
# 15176  This CD is of low quality: I believe that this...      0
# 15177  Find another fish oil supplement: I didn't eve...      0
# 15179  Not user-friendly: I am returning this item be...      0
# 15180  Very disappointing: Based on the reviews I rea...      0
# 15187  WORST GUN EVER: I bought this gun thinking it ...      0
# 15194  gerber just tarnished their rep with chinese j...      0
# 15197  Nice idea, but...: Purchased based on other re...      0
# 15200  This is so fake: If you are an exorcist fan an...      0
# 15201  Franklin's Magic Christmas: Bah! Humbug! Sure ...      0
# 15206  Waste of time: This book is filled with curses...      0
# 15208  What to use this line for?: As a level fly lin...      0
# 15210  really surprised by the praise of all fans: Th...      0
# 15217  Several problems with this crib: Although it w...      0
#
# [7500 rows x 2 columns]

# %%
final
# Out:
#                                                   review  label
# 9884   This is all I expected !!!: I bought this with...      1
# 10210  What a Cop Out!: Bringing Frank back was a gre...      0
# 6213   The funniest movie I have ever seen!: I am ver...      1
# 2805   Didn't like the paper quality and presentation...      0
# 14874  This moview was horrible. Buy Cops and Robbers...      0
# 515    no color, no buy: I wanted very much to get a ...      0
# 7561   Great workhorse: I've been using this router f...      1
# 3022   WHY???: I was definitely turned on by all of t...      0
# 11955  not good: The dolphins screach, it's awful. Th...      0
# 13097  not funny: dry predictable and frankly not bel...      0
# 13521  A very funny contemporary romance: I loved thi...      1
# 2826   The gateway to another world!: I started the b...      1
# 5040   best b-70: this is my second one B-70 for the ...      1
# 929    Could never read this book....: This is what I...      0
# 6534   Shrunk and See Through: These leggings shrink ...      0
# 10303  Good scholarship, bad conclusions: Herman just...      0
# 7832   A waste of time: Have you ever rented a movie,...      0
# 2514   Most Disappointed: Well, how can I review this...      0
# 13497  Shoddy, unprofessional copy - don't buy it: I ...      0
# 15166  Take Heed!: As most of the other reviewers hea...      0
# 11487  Overall, a very good and versatile design, of ...      1
# 13514  What's that smell? Oh . . . it's cheese.: This...      0
# 8369   box set dvd: this order was very well packaged...      1
# 13034  Big Hemingway fan: Very well written with lot'...      1
# 6577   Good Entry HTPC case.: The Antec NSK2400 case ...      1
# 12619  Short story; long book; insurance guy playing ...      0
# 4970   Where struggle ends and grace begins: I first ...      1
# 5249   Gets the job done.: This drying rack gets the ...      1
# 6594   100 Times Better Than Jason Hunter's book...: ...      1
# 7983   Great Story: Sinsiter Enough to make Stephen K...      1
# ...                                                  ...    ...
# 1348   DO NOT PURCHASE: I have actually not yet had t...      0
# 13995  Very boring book: It's one of the worst book I...      0
# 3406   Another Quality Heritage Release: This review ...      1
# 11611  the worst toy ever that has been made on earth...      0
# 3321   MOIVES ON PARADE! DO NOT ORDER-ITS WORST COPY ...      0
# 10297  most pain free way to learn sounds of the alph...      1
# 2522   Disgusted: I was disgusted by the grotesque di...      0
# 11924  gluten free cycle works great!: Pros: Price wa...      1
# 13639  Best tea I've ever had: This tea is delicious!...      1
# 2374   Fantasy or reality: I have always loved this m...      1
# 4156   Harry Potter Rides Again: Another fine adaptat...      1
# 12011  I swear that when I ordered this "puppy" was n...      0
# 1525   Decent Tunes.: I'm not really into pop music. ...      1
# 14210  Review of 3D vs. 2D: We need about 1,000,000 r...      0
# 13365  3.5 stars out of 4: The Bottom Line:A classic ...      1
# 1596   smack the editors: As mentioned by other revie...      0
# 9962   Great ideas!!: I bought this book for my Maste...      1
# 4348   BO-RING!: This book by far is the worst piece ...      0
# 526    A Must read: This book and author were intervi...      1
# 6210   CROSLEY CR248 SONGWRITER CD RECORDER: THIS MAC...      0
# 11557  Fundamental flaw (so does price really matter?...      0
# 5913   Great film, good DVD: First of all: Mister " t...      1
# 6545   The dreaded STP error: It's amazing to me that...      0
# 2980   Crap: with all the add on to this game a simpl...      0
# 13955  this pan is great: this pan made a Calphalon f...      1
# 2130   A Story Everyone Must Know...: Secret of the W...      1
# 7108   Garbage at it's finest: This album is the prim...      0
# 14291  ol western: Thank u for this DVD my Grandma tr...      1
# 1048   Una porqueria no compre: Total porqueria de re...      0
# 11052  The Fighting Agents - W.E.B.Griffin - UNABRIDG...      0
#
# [15000 rows x 2 columns]
