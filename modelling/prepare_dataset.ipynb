# %%
import pandas as pd

# %%
# read reviews file
with open('test.ft.txt', 'r', encoding="utf8") as f:
    contents = f.readlines()

# %%
# create a blank reviews dictionary
reviews = {
    'review': [],
    'label': [],
}

# iterate over contents and push them in the reviews dictionary
for content in contents:
    label = reviews['label'].append(content[0:10])
    review = reviews['review'].append(content[11:-1])
    
# create dataframe from reviews dictionary 
dataframe = pd.DataFrame(reviews)

# convert labels from text to number
dataframe['label'] = dataframe['label'].apply(lambda label: 0 if label == '__label__1' else 1)

# %%
dataframe.to_csv('Amazon_Reviews_All.csv', index=False)

# %%
# count positive and negative labels
dataframe['label'].value_counts()
# Out:
# 1    200000
# 0    200000
# Name: label, dtype: int64

# %%
positive = dataframe[dataframe['label'] == 1].iloc[0:2000]

# %%
negative = dataframe[dataframe['label'] == 0].iloc[0:2000]

# %%
final = positive.append(negative)

# %%
# randomize the dataset
final = final.sample(frac=1)

# save to file
final.to_csv('Amazon_Reviews.csv', index=False)

# %%
positive
# Out:
#                                                  review  label
# 0     Great CD: My lovely Pat has one of the GREAT v...      1
# 1     One of the best game music soundtracks - for a...      1
# 3     works fine, but Maha Energy is better: Check o...      1
# 4     Great for the non-audiophile: Reviewed quite a...      1
# 8     Unique Weird Orientalia from the 1930's: Exoti...      1
# 10    Great book for travelling Europe: I currently ...      1
# 13    TRULY MADE A DIFFERENCE!: I have been using th...      1
# 16    Simple, Durable, Fun game for all ages: This i...      1
# 17    Review of Kelly Club for Toddlers: For the pri...      1
# 18    SOY UN APASIONADO DEL BOX: Y ESTE LIBRO ESTÁ E...      1
# 19    Some of the best fiddle playing I have heard i...      1
# 22    one of the last in the series to collect !: Th...      1
# 23    Sony Hi8 Camcorder with 2.5 LCD: I believe I w...      1
# 26    works great: i bought this item to connect to ...      1
# 28    wish i had gotten this sooner!: ive got a lamp...      1
# 30    This is the all time best book!: This is the a...      1
# 31    Mary Ash: Can't believe I have never reviewed ...      1
# 32    Tha BOMB of a book!!: L.J. Smith is the best a...      1
# 33    This book was a great book that i have read ma...      1
# 34    They'd watch it nonstop if I'd let them: apart...      1
# 36    Wonderful: I went online for information about...      1
# 38    Book of Chance: I had just finished reading 'T...      1
# 40    WeiB FOREVER!: This is a great CD!! I love Wei...      1
# 42    Real HTML for people who build sites for a liv...      1
# 43    Marriage has its good and bad moments: This is...      1
# 44    Amazing...: love it...very touch.it's to bad t...      1
# 45    Leslie in a nutshell: Danelectro DJ-20C Rocky ...      1
# 49    Patricia Cornwell has turned me into a reader:...      1
# 50    Best of the First Four in this series.: This i...      1
# 51    Great Beginning...poor ending: Parricia Corwel...      1
# ...                                                 ...    ...
# 3847  Unique Subject Matter: "Come to Me" is a book ...      1
# 3851  Great book, great information, great photograp...      1
# 3852  A Good Resource Book: Grasping God's Word make...      1
# 3854  Run a full size smaller - but toasty warm: I h...      1
# 3856  Warm but less than perfect: Shearling is the b...      1
# 3857  Good Christmas Present: My wife asked for slip...      1
# 3859  Great for the price.: I bought these when they...      1
# 3860  Fixed more than Our Table Issues (no doubt!): ...      1
# 3861  Widge: I like this product when using my Bosch...      1
# 3865  Great look at the feastival!: I thought this w...      1
# 3866  Loved This Book!: Really opened my eyes on the...      1
# 3867  Box Of Hair: I heard that Cub broke up. If it'...      1
# 3874  How to create comics from the man who changed ...      1
# 3875  love this book: I love this book for reference...      1
# 3876  My Great Aunt Arizona: This is a wonderful boo...      1
# 3877  Great, so where is it now?: If you like Seal a...      1
# 3879  Olivia, the vocalist: While promoting this alb...      1
# 3883  James Last Tango: This is a fantastic CD, and ...      1
# 3884  The day the world came to town: Having recentl...      1
# 3885  A different look at 9/11: I really enjoyed thi...      1
# 3886  They work!: I have tried every ice pack on the...      1
# 3887  My 2 year old literally took his breath away h...      1
# 3888  Mom of twins equals needs something durable!: ...      1
# 3892  And most important, my wife likes it....: I wa...      1
# 3894  X-Pulse: Get your heatbeat pounding with the n...      1
# 3900  Steve Au: This pacifier was the best part of m...      1
# 3901  last recordng by the best sax player of his ge...      1
# 3902  Love it.: I got this as a used product and got...      1
# 3904  These are gorgeous!: I would expect to pay 6 t...      1
# 3907  Great price fast shipping: I odered standard s...      1
#
# [2000 rows x 2 columns]

# %%
negative
# Out:
#                                                  review  label
# 2     Batteries died within a year ...: I bought thi...      0
# 5     DVD Player crapped out after one year: I also ...      0
# 6     Incorrect Disc: I love the style of this, but ...      0
# 7     DVD menu select problems: I cannot scroll thro...      0
# 9     Not an "ultimate guide": Firstly,I enjoyed the...      0
# 11    Not!: If you want to listen to El Duke , then ...      0
# 12    A complete Bust: This game requires quicktime ...      0
# 14    didn't run off of USB bus power: Was hoping th...      0
# 15    Don't buy!: First of all, the company took my ...      0
# 20    Long and boring: I've read this book with much...      0
# 21    Dont like it: This product smells when you ope...      0
# 24    Don't Take the Chance - Get the SE Branded Cab...      0
# 25    Waste of money!: Like many of the Barbie CD Ro...      0
# 27    Has No Range: I suppose if you were going to s...      0
# 29    Three Days of Use and It Broke: Very disappoin...      0
# 35    Not as expected...: My children get easily bor...      0
# 37    Doublecharged for shipping because merchant wa...      0
# 39    Light reading, light in substance: A clichéd s...      0
# 41    Great Book--unacceptable condition: I was look...      0
# 46    More Romance Please and Less Mystery!!: the re...      0
# 47    A Lost Author: I have read all of the Carpathi...      0
# 48    Okay but Messy....: We purchased this bag for ...      0
# 52    12 Y/O Potty Humor From 40 somethings does not...      0
# 53    I wish Adam Sandler wasn't in this.: I should ...      0
# 56    Disappointment at it's extreme: I had never re...      0
# 61    Predictable & has a lame ending: I have read a...      0
# 63    A historical gem whose title obscures its inte...      0
# 64    Vastly overrated work of fiction: I was sorely...      0
# 67    Had to return it: The sizing is perfect and a ...      0
# 68    Broke the 2nd time I wore it, great until then...      0
# ...                                                 ...    ...
# 4040  Read The Club Dumas instead.: I bought this bo...      0
# 4041  Yawn: A handsome priest is sent by the Vatican...      0
# 4043  Don't Bother: I had really grown to enjoy Pere...      0
# 4044  Review fraud: The Institute for American India...      0
# 4045  TOO VAGUE: I found this book to lack depth and...      0
# 4046  NOT MADE FOR THE REAL MOBILE DJ: IT DOESENT HA...      0
# 4047  weakest of the series....: I have liked all of...      0
# 4049  A Book with Some Gorey Details: Heart of a Jag...      0
# 4050  YAYA: The Heart of a Jaguar was a pretty o.k. ...      0
# 4052  locking cap?: seemed like a nice heavy steel c...      0
# 4054  A boring story in N.Orleans: The most boring s...      0
# 4055  BOOOOOOOOOOOOOOOOORING!!!!!!!!!!!!!!!!!!!!!!!:...      0
# 4056  Beware: These chairs look good in the picture,...      0
# 4057  Safety questionable: I'm returning this car se...      0
# 4064  It made no sense: I should have looked before ...      0
# 4068  Mediocre at best: Happy Hooker is neither a bo...      0
# 4069  Errors and more errors: I was so excited to ge...      0
# 4070  Please.....: Come on....the number of errors.I...      0
# 4071  Lives in denial: Having read most books on Kri...      0
# 4072  Warning will not play: WARNING....be careful o...      0
# 4074  not what you think: First off this helmet is e...      0
# 4075  One Star for Amazon!: All the stars in the hea...      0
# 4083  "I love you, little one": Overuse, and imprope...      0
# 4085  I think I've read this before.: Wow. I've neve...      0
# 4086  horrible: One of the worst books I have ever r...      0
# 4088  Cute story but its been done: While I applaud ...      0
# 4089  Bland.: The kind of repetetive, banal, Tolkien...      0
# 4090  Rip Off: This book was The Dragonriders, LOTR,...      0
# 4091  If their was a -5 Star... I would choose it..:...      0
# 4094  it's not worth reading: There are a lot of one...      0
#
# [2000 rows x 2 columns]

# %%
final
# Out:
#                                                  review  label
# 3782  Great transmitter but not universal: I ordered...      1
# 378   Great movie and terrific views of the Dingle p...      1
# 3891  Book Critic2: I was a little dissapointed with...      0
# 939   Beware of editions by General Books LLC: Bewar...      0
# 3079  Awesome Picture!!!: Now this is what High Defi...      1
# 137   Off and on: Its hard to find these types of ch...      0
# 1026  definitely the best horror\suspense book I kno...      1
# 2872  High quality, casino-grade poker chip set: Cas...      1
# 576   Informative but idiosyncratic coverage of hist...      0
# 2203  Bring the old type back: At least with the old...      0
# 1613  Easy to follow: This is a quick reference or t...      1
# 690   Touching: Beautiful film, excellent acting. Th...      1
# 2494  Not just for breast feeding moms :-): Three wo...      1
# 2021  COOL: Awsome cd...almost evry song is worth li...      1
# 1481  Plenty of Emotion: I don't agree that Clay sho...      1
# 442   These Shoes are made for walking.: In the Merr...      1
# 2757  Evolution is true: Science in no way refutes e...      0
# 313   Lacking: The movie was fine to watch but it wa...      0
# 1867  A New Batman: I have all the Batman Series of ...      1
# 2156  Too much is not enough: My boys, ages 5 and 7,...      1
# 457   Great Bed for Guests: Bought this for my Grand...      1
# 2113  Best Book on VB.NET I've Found: This is far an...      1
# 2356  The Origin of Betty Boop!: Helen Kane is the f...      1
# 2096  Looked cool :(: I am an avid ps2 gamer. I purc...      0
# 2674  A very beautiful coffee table book...: I love ...      1
# 353   Transformers: Dark of the Moon: watched this o...      1
# 271   Tiene que ser sensilla!!: Quien no va a ser se...      0
# 2144  Great Puzzle: Although it took a long time to ...      1
# 3159  Too drawn out!: I usually enjoy reading this a...      0
# 750   The greatest work of the 20th Century: What ca...      1
# ...                                                 ...    ...
# 363   Totally Useless: I too bought into the hype th...      0
# 3119  The Count of Monte Cristo (Oxford world Classi...      1
# 1383  Poetry with a knack for memorable imagery.: Pa...      1
# 3825  Nice supplement to study Meisner work.: Nice e...      1
# 3328  Now thats what I call a bible: Fantastic - it ...      1
# 170   One of my favorites as a kid: I loved this boo...      1
# 1099  I want to like this.: The tracks are great.The...      0
# 1514  It hurts: It hurts to see Clay fall like this....      0
# 1931  The Train Delivers!: Originally I purchased th...      1
# 1250  anything KMFDM: Better than 2002 tour - BUT GU...      1
# 3145  good for a b-day prsent?: my brother loves the...      0
# 2667  good piece of collection: This video reflects ...      1
# 3226  Mindless, Pointless and Insulting: Bad. Just p...      0
# 3612  What a disappointment!: John Grisham should st...      0
# 394   Non Computer Geek: STAY AWAY FROM THIS PRINTER...      0
# 3308  Korean movie The Great Queen Seondeok: Great m...      1
# 3215  Chilling!: I've been a Morphine fan for quite ...      1
# 421   It's too simple even for a KISS book: I know t...      0
# 625   Not a good toy: This toy isn't well made or de...      0
# 1069  Holds #1, not #2: The title says it all. I nev...      0
# 1443  Of mice and men - Izzy G: Of mice and men was ...      1
# 1789  why do you pay someone to write your reviews?:...      0
# 386   Is honesty always rewarded ?: Puss in Boots is...      1
# 2550  THE favorite book in our house.: We love readi...      1
# 2828  Great book: Very enjoyable you can never stop ...      1
# 4071  Lives in denial: Having read most books on Kri...      0
# 2677  Great Book on the Best Computer: This is a gre...      1
# 2121  It's not hype!: This book has so many pearls o...      1
# 1511  nothing out of the ordinary: This man really d...      0
# 1700  VTech i6775 Review: Years ago, I had purchased...      0
#
# [4000 rows x 2 columns]
